# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import pandas as pd
data = pd.read_csv('zdataold_2.csv', encoding="ISO-8859-1")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10888 entries, 0 to 10887
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         10888 non-null  int64
#  1   Restaurant Name       10888 non-null  object
#  2   Country Code          10888 non-null  int64
#  3   City                  10888 non-null  object
#  4   Address               10888 non-null  object
#  5   Locality              10888 non-null  object
#  6   Locality Verbose      10888 non-null  object
#  7   Longitude             10888 non-null  float64
#  8   Latitude              10888 non-null  float64
#  9   Cuisines              10888 non-null  object
#  10  Average Cost for two  10888 non-null  int64
#  11  Currency              10888 non-null  object
#  12  Has Table booking     10888 non-null  object
#  13  Has Online delivery   10888 non-null  object
#  14  Is delivering now     10888 non-null  object
# ...

# %%
data.drop(data['Country Code'],)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10888 entries, 0 to 10887
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         10888 non-null  int64
#  1   Restaurant Name       10888 non-null  object
#  2   Country Code          10888 non-null  int64
#  3   City                  10888 non-null  object
#  4   Address               10888 non-null  object
#  5   Locality              10888 non-null  object
#  6   Locality Verbose      10888 non-null  object
#  7   Longitude             10888 non-null  float64
#  8   Latitude              10888 non-null  float64
#  9   Cuisines              10888 non-null  object
#  10  Average Cost for two  10888 non-null  int64
#  11  Currency              10888 non-null  object
#  12  Has Table booking     10888 non-null  object
#  13  Has Online delivery   10888 non-null  object
#  14  Is delivering now     10888 non-null  object
# ...

# %%
data['Address'].unique()
#data['Locality'].unique()
# Out:
# array(['Aaya Nagar, New Delhi',
#        '84, Near Honda Showroom, Adchini, New Delhi',
#        '81/3, 1st Floor, Qutub Residency, Adchini, New Delhi', ...,
#        '57/12, Main Road, Zakir Nagar, New Delhi',
#        '92/17, Zakir Nagar, New Delhi',
#        'Jamia Nagar, Zakir Nagar, New Delhi'], dtype=object)

# %%
data=data.drop("Country Code", axis='columns')
data=data.drop("City", axis='columns')
data=data.drop("Locality Verbose", axis='columns')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10888 entries, 0 to 10887
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         10888 non-null  int64
#  1   Restaurant Name       10888 non-null  object
#  2   Address               10888 non-null  object
#  3   Locality              10888 non-null  object
#  4   Longitude             10888 non-null  float64
#  5   Latitude              10888 non-null  float64
#  6   Cuisines              10888 non-null  object
#  7   Average Cost for two  10888 non-null  int64
#  8   Currency              10888 non-null  object
#  9   Has Table booking     10888 non-null  object
#  10  Has Online delivery   10888 non-null  object
#  11  Is delivering now     10888 non-null  object
#  12  Switch to order menu  10888 non-null  object
#  13  Price range           10888 non-null  int64
#  14  Aggregate rating      10888 non-null  float64
# ...

# %%
data['Switch to order menu'].unique()
# Out:
# array(['No'], dtype=object)

# %%
data=data.drop("Currency", axis='columns')
data=data.drop("Longitude", axis='columns')
data=data.drop("Latitude", axis='columns')
data=data.drop("Has Table booking", axis='columns')
data=data.drop("Has Online delivery", axis='columns')
data=data.drop("Switch to order menu", axis='columns')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10888 entries, 0 to 10887
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         10888 non-null  int64
#  1   Restaurant Name       10888 non-null  object
#  2   Address               10888 non-null  object
#  3   Locality              10888 non-null  object
#  4   Cuisines              10888 non-null  object
#  5   Average Cost for two  10888 non-null  int64
#  6   Is delivering now     10888 non-null  object
#  7   Price range           10888 non-null  int64
#  8   Aggregate rating      10888 non-null  float64
#  9   Rating color          10888 non-null  object
#  10  Rating text           10888 non-null  object
#  11  Votes                 10888 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1020.9+ KB

# %%
data['Votes'].unique()
# Out:
# array([   2,   46,   45,   11,  238,    8,   64,  113,   66,  141,   77,
#          40,  665,   31,   32,   83,  288,   33,   26,    0,   49,   13,
#         167,   99,  125,  124,   79,   20,   23,   19,    7,   35,   10,
#          42,   21,   16,   37,    4,   22,   97,  452,   14,   82,    1,
#         100,  230,  458,  176,  232,   27,  210,   44,  206,  185,  256,
#         336,  280, 2131,   38,   69,    6,   80,   24,   12,    9,   18,
#           5,  251,  220,   34,  103,   62,   58,  106,   48,   51,   59,
#         188,  387,  117,  102,   15,   17,  135,   74,  191,  199,   60,
#           3,   29,  278,   53,  142,   41,  492,   28,  457,  173,  131,
#         123,  274,   87,   78,  101,   96,   70,  560,  421,   68,   85,
#         343,  120,   55,   90,  161,   67,  239,  137,  212,  193,  202,
#         332,   92,  158,   98,   71,  203,  218,  164,  138,  225,   39,
#          57,   30,  112,  116,  444,  163,   63,   43, 1487,  752,  437,
# ...

# %%
data=data.drop("Restaurant ID", axis='columns')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10888 entries, 0 to 10887
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       10888 non-null  object
#  1   Address               10888 non-null  object
#  2   Locality              10888 non-null  object
#  3   Cuisines              10888 non-null  object
#  4   Average Cost for two  10888 non-null  int64
#  5   Is delivering now     10888 non-null  object
#  6   Price range           10888 non-null  int64
#  7   Aggregate rating      10888 non-null  float64
#  8   Rating color          10888 non-null  object
#  9   Rating text           10888 non-null  object
#  10  Votes                 10888 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 935.8+ KB

# %%
cor=data['Locality'].corr(data['Cuisines'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-66bba12426e0> in <module>()
# ----> 1 cor=data['Locality'].corr(data['Cuisines'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2507         if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2508             return nanops.nancorr(
# -> 2509                 this.values, other.values, method=method, min_periods=min_periods
#    2510             )
#    2511
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# ...

# %%
#data['Cuisines'].value_counts().idxmax()
print(data.Cuisines.mode())
# Out:
# 0    NorthIndian
# dtype: object

# %%
grouped=data.groupby(['Locality', 'Cuisines']).size().groupby(level=1).max()

# %%
grouped.head(35)
# Out:
# Cuisines
# Afghani           3
# African           1
# American         10
# Andhra            1
# Arabian           2
# Armenian          2
# Asian            11
# Assamese          1
# Awadhi            1
# Bakery           12
# Bengali           4
# Beverages         9
# Bihari            1
# Biryani           6
# British           1
# Burger            9
# Burmese           1
# Cafe             32
# Chettinad         1
# Chinese          40
# Continental      34
# CuisineVaries     1
# Deli              1
# Desserts         13
# DrinksOnly        1
# European         10
# FastFood         26
# FingerFood        7
# French            1
# Goan              1
# Gujarati          1
# HealthyFood       6
# Hyderabadi        2
# IceCream          6
# Indian            1
# dtype: int64

# %%
group=data.groupby(['Locality','Cuisines']).count()

# %%
group.head(35)
# Out:
#                                              Restaurant Name  Address  \
# Locality                      Cuisines
# ARSS Mall, Paschim Vihar      Chinese                      1        1
#                               FastFood                     1        1
#                               Mithai                       1        1
#                               NorthIndian                  1        1
#                               SouthIndian                  1        1
# Aaya Nagar                    CuisineVaries                1        1
# Adchini                       Andhra                       1        1
#                               Chinese                      3        3
#                               Continental                  2        2
#                               FastFood                     2        2
#                               Goan                         1        1
#                               Italian                      1        1
# ...

# %%
grouped=data.groupby(['Locality','Cuisines']).max(data['Cuisines'].count())

# %%
grouped.head(20)
# Out:
#                                         Average Cost for two  Price range  \
# Locality                 Cuisines
# ARSS Mall, Paschim Vihar Chinese                         500            2
#                          FastFood                        500            2
#                          Mithai                          500            2
#                          NorthIndian                     500            2
#                          SouthIndian                     500            2
# Aaya Nagar               CuisineVaries                   500            2
# Adchini                  Andhra                         1200            3
#                          Chinese                        1500            3
#                          Continental                    1500            3
#                          FastFood                        400            1
#                          Goan                           1200            3
# ...
